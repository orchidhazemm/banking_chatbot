# %%
from geopy.distance import distance

# Example Bank Misr branch data (dummy data for illustration)
bank_branches = [
    {"name": "Branch A", "location": (30.1234, 31.5678)},
    {"name": "Branch B", "location": (30.2345, 31.6789)},
    # Add more branches here
]


def find_nearest_branch(user_location):
    nearest_branches = []
    for branch in bank_branches:
        branch_location = branch["location"]
        # Calculate distance in kilometers
        dist = distance(user_location, branch_location).km
        nearest_branches.append((branch["name"], dist))

    nearest_branches.sort(key=lambda x: x[1])  # Sort branches by distance
    return nearest_branches[:2]  # Return the two nearest branches


# Example usage
# Replace with actual user coordinates
user_latitude, user_longitude = 30.138908,  31.239346
user_location = (user_latitude, user_longitude)
nearest_branches = find_nearest_branch(user_location)

# Chatbot response
if nearest_branches:
    response = f"Here are the Bank Misr branches nearest to you:\n"
    for branch, dist in nearest_branches:
        response += f"- {branch}: {dist:.2f} km away\n"
else:
    response = "I'm sorry, I couldn't find any Bank Misr branches near your location."

print(response)
# Out:
# Here are the Bank Misr branches nearest to you:
# - Branch A: 31.70 km away
# - Branch B: 43.64 km away

# %%
from geopy.geocoders import Nominatim
import requests


def get_location_by_ip():
    response = requests.get('https://ipinfo.io')
    data = response.json()
    location = data['loc'].split(',')
    latitude = float(location[0])
    longitude = float(location[1])
    return latitude, longitude


def get_location_details(latitude, longitude):
    # Initialize geocoder
    geolocator = Nominatim(user_agent="geoapiExercises")

    # Reverse geocoding to get location details
    location = geolocator.reverse((latitude, longitude), exactly_one=True)
    return location


# Get latitude and longitude using IP
user_latitude, user_longitude = get_location_by_ip()

# Get detailed location information
location_details = get_location_details(user_latitude, user_longitude)

print(f"Latitude: {user_latitude}, Longitude: {user_longitude}")
print(f"Location: {location_details}")
# Out:
# Latitude: 30.0626, Longitude: 31.2497
# Location: شارع رمسيس, الفجاله, السكاكيني, القاهرة, 11577, مصر

# %%
def get_location_by_ip():
    response = requests.get('https://ipinfo.io')
    data = response.json()
    location = data['loc'].split(',')
    latitude = float(location[0])
    longitude = float(location[1])
    return latitude, longitude


get_location_by_ip()
# Out:
# (30.0626, 31.2497)

# %%
from geopy.distance import distance

# Example Bank Misr branch data (dummy data for illustration)
bank_branches = [
    {"name": "Branch A", "location": (30.1234, 31.5678)},
    {"name": "Branch B", "location": (30.2345, 31.6789)},
    # Add more branches here
]


def find_nearest_branch(user_location):
    nearest_branches = []
    for branch in bank_branches:
        branch_location = branch["location"]
        # Calculate distance in kilometers
        dist = distance(user_location, branch_location).km
        nearest_branches.append((branch["name"], dist))

    nearest_branches.sort(key=lambda x: x[1])  # Sort branches by distance
    return nearest_branches[:2]  # Return the two nearest branches


# Example usage
# Replace with actual user coordinates
user_location = (user_latitude, user_longitude)
nearest_branches = find_nearest_branch(user_location)

# Chatbot response
if nearest_branches:
    response = f"Here are the Bank Misr branches nearest to you:\n"
    for branch, dist in nearest_branches:
        response += f"- {branch}: {dist:.2f} km away\n"
else:
    response = "I'm sorry, I couldn't find any Bank Misr branches near your location."

print(response)
# Out:
# Here are the Bank Misr branches nearest to you:
# - Branch A: 35.44 km away
# - Branch B: 45.98 km away

# %%
import googlemaps

# Replace with your actual Google Maps API key
API_KEY = 'AIzaSyBODXo__-1DIwAQlefSh0Z0nsobWez08c8'
gmaps = googlemaps.Client(key=API_KEY)

# Function to get Bank Misr branches near a specific location


def find_nearby_branches(latitude, longitude, radius=500000, keyword="Banque Misr"):
    # Define the location as a tuple of (latitude, longitude)
    location = (latitude, longitude)

    # Use the Places API to find nearby Bank Misr branches
    places_result = gmaps.places_nearby(
        location=location, radius=radius, keyword=keyword)

    # Extract information about the branches
    branches = []
    for place in places_result['results']:
        branch_name = place['name']
        branch_location = place['geometry']['location']
        branch_address = place.get('vicinity', 'Address not available')
        branches.append({
            "name": branch_name,
            "location": (branch_location['lat'], branch_location['lng']),
            "address": branch_address
        })

    return branches


# Find nearby Bank Misr branches
nearby_branches = find_nearby_branches(user_latitude, user_longitude)

# Print the details of the nearby branches
for branch in nearby_branches:
    print(f"Branch Name: {branch['name']}")
    print(f"Location: {branch['location']}")
    print(f"Address: {branch['address']}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 34
#      30     return branches
#      33 # Find nearby Bank Misr branches
# ---> 34 nearby_branches = find_nearby_branches(user_latitude, user_longitude)
#      36 # Print the details of the nearby branches
#      37 for branch in nearby_branches:
#
# NameError: name 'user_latitude' is not defined

# %%
len(nearby_branches)
# Out:
# 20

# %%
import googlemaps

# Replace with your actual Google Maps API key
gmaps = googlemaps.Client(key=API_KEY)

# Function to get Bank Misr branches near a specific location and generate Google Maps links


def find_nearby_branches(latitude, longitude, radius=500000, keyword="Banque Misr"):
    # Define the location as a tuple of (latitude, longitude)
    location = (latitude, longitude)

    # Use the Places API to find nearby Bank Misr branches
    places_result = gmaps.places_nearby(
        location=location, radius=radius, keyword=keyword)

    # Extract information about the branches and create Google Maps links
    branches = []
    for place in places_result['results']:
        branch_name = place['name']
        branch_location = place['geometry']['location']
        branch_address = place.get('vicinity', 'Address not available')

        # Create a Google Maps URL for the branch location
        maps_url = f"https://www.google.com/maps/search/?api=1&query={branch_location['lat']},{branch_location['lng']}"

        branches.append({
            "name": branch_name,
            "location": (branch_location['lat'], branch_location['lng']),
            "address": branch_address,
            "maps_url": maps_url
        })

    return branches


# Example usage: Assuming you have the user's latitude and longitude

# Find nearby Bank Misr branches
nearby_branches_1 = find_nearby_branches(user_latitude, user_longitude)

# Print the details of the nearby branches with Google Maps links
for branch in nearby_branches:
    print(f"Branch Name: {branch['name']}")
    print(f"Location: {branch['location']}")
    print(f"Address: {branch['address']}")
    print(f"Google Maps Link: {branch['maps_url']}\n")
# Out:
# Branch Name: Banque Misr
# Location: (30.0631734, 31.3375143)
# Address: 38 Abbas El-Akkad, Al Manteqah Al Oula, Nasr City
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 47
#      45 print(f"Location: {branch['location']}")
#      46 print(f"Address: {branch['address']}")
# ---> 47 print(f"Google Maps Link: {branch['maps_url']}\n")
#
# KeyError: 'maps_url'

# %%
# Function to get the coordinates of a specific address
def get_coordinates(address):
    geocode_result = gmaps.geocode(address)
    if geocode_result:
        location = geocode_result[0]['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    return None, None


# Example usage: Replace with the actual branch address
branch_address = "4777+PXJ, Bahtim, Shubra El Kheima 2, Al-Qalyubia Governorate 6220142"
branch_latitude, branch_longitude = get_coordinates(branch_address)

if branch_latitude and branch_longitude:
    print(f"Branch Address: {branch_address}")
    print(f"Latitude: {branch_latitude}")
    print(f"Longitude: {branch_longitude}")
    print(
        f"Google Maps Link: https://www.google.com/maps/search/?api=1&query={branch_latitude},{branch_longitude}")
else:
    print("Coordinates not found for the given address.")
# Out:
# Branch Address: 4777+PXJ, Bahtim, Shubra El Kheima 2, Al-Qalyubia Governorate 6220142
# Latitude: 30.1143375
# Longitude: 31.2648906
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=30.1143375,31.2648906

# %%
def find_nearby_branches(latitude, longitude, radius=500000, keyword="Banque Misr"):
    try:
        # Define the location as a tuple of (latitude, longitude)
        location = (latitude, longitude)

        # Use the Places API to find nearby Bank Misr branches
        places_result = gmaps.places_nearby(
            location=location, radius=radius, keyword=keyword, )

        branches = []
        for place in places_result['results']:
            branch_name = place['name']
            branch_location = place['geometry']['location']
            branch_address = place.get('vicinity', 'Address not available')

            # Create a Google Maps URL for the branch location
            maps_url = f"https://www.google.com/maps/search/?api=1&query={branch_location['lat']},{branch_location['lng']}"

            branches.append({
                "name": branch_name,
                "location": (branch_location['lat'], branch_location['lng']),
                "address": branch_address,
                "maps_url": maps_url
            })
        return branches
    except googlemaps.exceptions.ApiError as e:
        print(f"API error occurred: {e}")
        return []


# Example usage: Assuming you have the user's latitude and longitude
user_latitude = 30.0444  # Example latitude (Cairo, Egypt)
user_longitude = 31.2357  # Example longitude (Cairo, Egypt)

# Find nearby Bank Misr branches
nearby_branches_2 = find_nearby_branches(user_latitude, user_longitude)

# Print the details of the nearby branches with Google Maps links
for branch in nearby_branches:
    print(f"Branch Name: {branch['name']}")
    print(f"Location: {branch['location']}")
    print(f"Address: {branch['address']}")
    print(f"Google Maps Link: {branch['maps_url']}\n")
# Out:
# Branch Name: Banque Misr
# Location: (30.0631734, 31.3375143)
# Address: 38 Abbas El-Akkad, Al Manteqah Al Oula, Nasr City
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 43
#      41 print(f"Location: {branch['location']}")
#      42 print(f"Address: {branch['address']}")
# ---> 43 print(f"Google Maps Link: {branch['maps_url']}\n")
#
# KeyError: 'maps_url'

# %%
len(nearby_branches_2)
# Out:
# 20

# %%
import time

# %%
def find_nearby_branches(latitude, longitude, radius=5000, keyword="Banque Misr"):
    # Define the location as a tuple of (latitude, longitude)
    location = (latitude, longitude)

    # Initialize the list to store all branches
    branches = []

    # Initial request to get the first 20 results
    places_result = gmaps.places_nearby(
        location=location, radius=radius, keyword=keyword)

    while True:
        for place in places_result['results']:
            branch_name = place['name']
            branch_location = place['geometry']['location']
            branch_address = place.get('vicinity', 'Address not available')

            # Create a Google Maps URL for the branch location
            maps_url = f"https://www.google.com/maps/search/?api=1&query={branch_location['lat']},{branch_location['lng']}"

            branches.append({
                "name": branch_name,
                "location": (branch_location['lat'], branch_location['lng']),
                "address": branch_address,
                "maps_url": maps_url
            })

        # Check if there's a next page token
        next_page_token = places_result.get('next_page_token')
        if not next_page_token:
            break

        # Wait a few seconds before requesting the next page of results
        # Google recommends waiting before using the next page token
        time.sleep(2)
        places_result = gmaps.places_nearby(
            location=location, radius=radius, keyword=keyword, page_token=next_page_token)

    return branches


# Example usage: Assuming you have the user's latitude and longitude
user_latitude = 30.0444  # Example latitude (Cairo, Egypt)
user_longitude = 31.2357  # Example longitude (Cairo, Egypt)

# Find nearby Bank Misr branches
nearby_branches_3 = find_nearby_branches(user_latitude, user_longitude)

# Print the details of the nearby branches with Google Maps links
for branch in nearby_branches:
    print(f"Branch Name: {branch['name']}")
    print(f"Location: {branch['location']}")
    print(f"Address: {branch['address']}")
    print(f"Google Maps Link: {branch['maps_url']}\n")
# Out:
# Branch Name: Banque Misr
# Location: (30.0387231, 31.2011417)
# Address: 29 Mossadak, Ad Doqi, Dokki
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=30.0387231,31.2011417
#
# Branch Name: Banque Misr
# Location: (30.0473665, 31.2458571)
# Address: 30 Roushdy Basha, As Sahah, Abdeen
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=30.0473665,31.2458571
#
# Branch Name: Banque Misr
# Location: (30.0191677, 31.22508029999999)
# Address: 269F+MXG, Al Manial, Al Manyal Al Gharbi, Old Cairo
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=30.0191677,31.22508029999999
#
# Branch Name: Banque Misr
# Location: (30.04378049999999, 31.2236345)
# Address: 3 شارع المنصور محمد، St, Zamalek
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=30.04378049999999,31.2236345
#
# Branch Name: Banque Misr
# Location: (30.05218589999999, 31.1922945)
# Address: 56-58 Syria, Mit Akaba, Agouza
# ...

# %%
import time

# %%
def fetch_places_for_location(latitude, longitude, radius, keyword):
    location = (latitude, longitude)
    places_result = gmaps.places_nearby(
        location=location, radius=radius, keyword=keyword)
    branches = []

    while True:
        for place in places_result['results']:
            branch_name = place['name']
            branch_location = place['geometry']['location']
            branch_address = place.get('vicinity', 'Address not available')

            maps_url = f"https://www.google.com/maps/search/?api=1&query={branch_location['lat']},{branch_location['lng']}"

            branches.append({
                "name": branch_name,
                "location": (branch_location['lat'], branch_location['lng']),
                "address": branch_address,
                "maps_url": maps_url
            })

        next_page_token = places_result.get('next_page_token')
        if not next_page_token:
            break

        time.sleep(2)
        places_result = gmaps.places_nearby(
            location=location, radius=radius, keyword=keyword, page_token=next_page_token)

    return branches


def find_nearby_branches(latitude, longitude, radius=5000, keyword="Banque Misr", grid_size=4):
    branches = []
    # Approx. conversion of meters to degrees (latitude)
    lat_step = radius / 111320
    # Approx. conversion of meters to degrees (longitude)
    lng_step = radius / (40075000 * abs(latitude) / 360)

    # Generate grid points based on the central location
    for i in range(-grid_size, grid_size + 1):
        for j in range(-grid_size, grid_size + 1):
            lat = latitude + i * lat_step
            lng = longitude + j * lng_step
            location_branches = fetch_places_for_location(
                lat, lng, radius, keyword)
            branches.extend(location_branches)

    return branches


# Example usage: Assuming you have the user's latitude and longitude
user_latitude = 30.0444  # Example latitude (Cairo, Egypt)
user_longitude = 31.2357  # Example longitude (Cairo, Egypt)

# Find all nearby Bank Misr branches within a larger area
all_branches = find_nearby_branches(user_latitude, user_longitude)

# Remove duplicates
unique_branches_4 = {
    f"{branch['location'][0]},{branch['location'][1]}": branch for branch in all_branches}

# Print the details of all branches with Google Maps links
for branch in unique_branches_4.values():
    print(f"Branch Name: {branch['name']}")
    print(f"Location: {branch['location']}")
    print(f"Address: {branch['address']}")
    print(f"Google Maps Link: {branch['maps_url']}\n")
# Out:
# Branch Name: Bank misr atm
# Location: (29.8980716, 31.2770744)
# Address: V7XG+6RG, Madinet Al Hawamdeyah, El Hawamdeya
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=29.8980716,31.2770744
#
# Branch Name: بنك مصر فرع البدرشين
# Location: (29.8463797, 31.2770966)
# Address: R7WG+GRV, Unnamed Rd, Madinet Al Badrashin, Badrshein
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=29.8463797,31.2770966
#
# Branch Name: Banque Misr
# Location: (29.9088558, 31.2894392)
# Address: 10 ش كورنيش النيل، الكورنيش، اسوان
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=29.9088558,31.2894392
#
# Branch Name: Banque Misr بنك مصر فرع سرايات المعادي
# Location: (29.9567564, 31.26097619999999)
# Address: 69 Rd 9, Maadi Al Khabiri Ash Sharqeyah, Maadi
# Google Maps Link: https://www.google.com/maps/search/?api=1&query=29.9567564,31.26097619999999
#
# Branch Name: بنك مصر
# Location: (29.9553117, 31.2762433)
# ...

# %%
len(unique_branches_4)
# Out:
# 108

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(unique_branches_4.values()))

# %%
df.head()
# Out:
#                                      name                         location  \
# 0                           Bank misr atm         (29.8980716, 31.2770744)
# 1                    بنك مصر فرع البدرشين         (29.8463797, 31.2770966)
# 2                             Banque Misr         (29.9088558, 31.2894392)
# 3  Banque Misr بنك مصر فرع سرايات المعادي  (29.9567564, 31.26097619999999)
# 4                                 بنك مصر         (29.9553117, 31.2762433)
#
#                                              address  \
# 0      V7XG+6RG, Madinet Al Hawamdeyah, El Hawamdeya
# 1  R7WG+GRV, Unnamed Rd, Madinet Al Badrashin, Ba...
# 2                 10 ش كورنيش النيل، الكورنيش، اسوان
# 3     69 Rd 9, Maadi Al Khabiri Ash Sharqeyah, Maadi
# 4       شارع ١٩٩ - قسم شرطة المعادي، حي ثكنات, Maadi
#
#                                             maps_url
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# ...

# %%
df.to_csv('branches_locations.csv', index=False)

# %%
df = pd.read_csv("branches_locations.csv")

# %%
df.head()
# Out:
#                                      name                         location  \
# 0                           Bank misr atm         (29.8980716, 31.2770744)
# 1                    بنك مصر فرع البدرشين         (29.8463797, 31.2770966)
# 2                             Banque Misr         (29.9088558, 31.2894392)
# 3  Banque Misr بنك مصر فرع سرايات المعادي  (29.9567564, 31.26097619999999)
# 4                                 بنك مصر         (29.9553117, 31.2762433)
#
#                                              address  \
# 0      V7XG+6RG, Madinet Al Hawamdeyah, El Hawamdeya
# 1  R7WG+GRV, Unnamed Rd, Madinet Al Badrashin, Ba...
# 2                 10 ش كورنيش النيل، الكورنيش، اسوان
# 3     69 Rd 9, Maadi Al Khabiri Ash Sharqeyah, Maadi
# 4       شارع ١٩٩ - قسم شرطة المعادي، حي ثكنات, Maadi
#
#                                             maps_url
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# ...

# %%
eval(df['location'][0])
# Out:
# 29.8980716

# %%
my_location = 30.1388403, 31.2396769

# %%
30.1375237, 31.2184777

# %%
from nearest_branches import get_nearby_banque_branches
from IPython.display import Markdown, display

# %%
display(Markdown(get_nearby_banque_branches()))
# Out:
# ## Nearest Banque Misr Branches to You:
# ### 1- Branch Name: Banque Misr Shoubra El Khiema Branch
# - **Address:** 4777+PXJ, Bahtim, Shubra El Kheima 2
# - **Google Maps**: [View on Google Maps](https://www.google.com/maps/search/?api=1&query=30.1143126,31.2648472)
# - **Distance:**: 3.64 km
#
# ### 2- Branch Name: Banque Misr - Aghakhan Branch
# - **Address:** 10 Tafteesh Al Rai, Asad, El Sahel
# - **Google Maps**: [View on Google Maps](https://www.google.com/maps/search/?api=1&query=30.1025466,31.24338299999999)
# - **Distance:**: 4.04 km
#
# ### 3- Branch Name: بنك مصر فرع الوراق
# - **Address:** 464C+52C، Corniche El Nil، EL WARAK, Al Giza
# - **Google Maps**: [View on Google Maps](https://www.google.com/maps/search/?api=1&query=30.1054537,31.22003419999999)
# - **Distance:**: 4.16 km
